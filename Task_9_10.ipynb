# %%
# https://docs.ray.io/en/latest/tune/examples/pbt_ppo_example.html
# https://docs.ray.io/en/latest/rllib/rllib-algorithms.html#dqn

from google.colab import drive
drive.mount('/content/drive')

# !pip install modin[ray]
# !pip install gymnasium
# !pip install "gymnasium[atari, accept-rom-license]"
# !pip install atari_py
from ray import tune
import pandas as pd
import matplotlib.pyplot as plt
from ray.rllib.algorithms.dqn import DQNConfig

config = DQNConfig().environment(env = "ALE/Breakout-v5").resources(num_gpus = 0).training(lr = 0.0001, train_batch_size = 256, double_q=True)

# config = {
#     "env": "ALE/KingKong-v5",
#     "double_q" : True,
#     "lr":0.00001
# }
results_DDQN = tune.run("DQN", name='v9', config=config, stop={"timesteps_total":50000}, local_dir='/content/drive/MyDrive/Deep Reinforcement Lab',
checkpoint_freq = 10, metric= "episode_reward_mean", mode = "max")

print("Best config: ", results_DDQN .get_best_config(metric="episode_reward_mean"))

import random

import ray
from ray import train, tune



stopping_criteria = {"training_iteration": 100, "episode_reward_mean": 300}

tuner = tune.Tuner(
    "SAC",
    tune_config=tune.TuneConfig(
        metric="episode_reward_mean",
        mode="max",
        num_samples=1,
    ),
    param_space={
        "env": "Humanoid-v2",
        "kl_coeff": 1.0,
        "num_workers": 4,
        "num_cpus": 1,  #cpu
        "num_gpus": 0,  #gpu
        "model": {"free_log_std": True},
        "lambda": 0.95,
        "clip_param": 0.2,
        "lr": 1e-4,
        "num_sgd_iter": tune.choice([10, 20, 30]),
        "sgd_minibatch_size": tune.choice([128, 512, 2048]),
        "train_batch_size": tune.choice([10000, 20000, 40000]),
    },
    run_config=train.RunConfig(stop=stopping_criteria),
)
results = tuner.fit()

ppo_output = pd.read_csv(PATH_TO_progress.csv)
plt.figure(figsize=(10,6))

plt.plot(ppo_output["episode_reward_mean"])
plt.title('Training Progress')
plt.xlabel('Training Iterations')
plt.ylabel('Episode Reward Mean')
plt.legend()
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# WARNING: Ignoring invalid distribution -andas (/usr/local/lib/python3.10/dist-packages)
# ...
# WARNING: Ignoring invalid distribution -andas (/usr/local/lib/python3.10/dist-packages)
# WARNING: Ignoring invalid distribution -andas (/usr/local/lib/python3.10/dist-packages)
# ...
# WARNING: Ignoring invalid distribution -andas (/usr/local/lib/python3.10/dist-packages)
# WARNING: Ignoring invalid distribution -andas (/usr/local/lib/python3.10/dist-packages)
# ...
# WARNING: Ignoring invalid distribution -andas (/usr/local/lib/python3.10/dist-packages)
# 2024-05-12 03:33:21,630	WARNING callback.py:136 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# ...
